# %% [markdown]
# # Sorted bar chart with counts

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use(["ggplot", "./example.mplstyle"])

source_path = os.path.join("data", "papers.csv")
papers_df = pd.read_csv(source_path)

# %% [markdown]
# ## Plot

# %%
column_names = papers_df.columns[12:16]
counts = papers_df[column_names].sum()
indices = np.argsort(counts)
y_position = np.arange(len(counts))

bars = plt.barh(y_position, counts[indices], height=0.5)
plt.gca().bar_label(bars, padding=7)
plt.xlabel("Number of papers")
plt.yticks(y_position, column_names[indices])
plt.savefig(os.path.join("out", f"Sorted bar chart with counts.png"))
plt.show()
